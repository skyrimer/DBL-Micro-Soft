# %%
import os
import sqlite3
import pandas as pd
from tqdm import tqdm
import re 

def get_local_data(query: str, path: str) -> pd.DataFrame:
    # Connect to the SQLite database using a context manager
    with sqlite3.connect(path) as connection:
        # Read the data into a DataFrame
        df = pd.read_sql_query(query, connection,
                                   dtype={k: v for k, v in DTYPES.items() if k not in ("tweet_creation_time", "user_creation_time")},
                                   index_col='tweet_id')
        df['tweet_creation_time'] = pd.to_datetime(df['tweet_creation_time'])
        df['user_creation_time'] = pd.to_datetime(df['user_creation_time'])
    
    return df

QUERY_ALL = """
SELECT 
    Users.user_id AS user_id, 
    Users.creation_time AS user_creation_time, 
    Tweets.replied_tweet_id,
    Tweets.creation_time AS tweet_creation_time,
    Tweets.tweet_id as tweet_id,
    Tweets.full_text
FROM Users
INNER JOIN Tweets ON Users.user_id = Tweets.user_id;
"""

DTYPES = {
"user_id": "object",
"user_creation_time": "datetime64[ns]",
"tweet_creation_time": "datetime64[ns]",
"tweet_id": "object",
"full_text": "object",
}



path =  os.path.join(
        os.path.dirname(
            os.getcwd()
            ),
    "data_processed", "local_backup.db")
test_data = get_local_data(QUERY_ALL, path)

test_data = test_data.reset_index()

# DONE!!!!!!!!!

airlines_id = ['56377143','106062176','18332190','22536055','124476322','26223583',
               '2182373406','38676903','1542862735','253340062','218730857','20626359',
               '45621423']

# List of airlines to search for in text
airlines = ['KLM', 'Lufthansa', 'American Air', 'RyanAir', 'British Airways', 'EasyJet', 
            'Air France', 'Singapore Airlines', 'Qantas', 'Etihad Airways', 'Air Berlin',
            'BritishAirways', 'AirFrance', 'SingaporeAirlines', 'EtihadAirways', 'AirBerlin',
            'AmericanAir', 'VirginAtlantic', 'Virgin Atlantic']

# %%
def create_pattern(airline):
    # Escape the airline name
    escaped_name = re.escape(airline)
    # Replace escaped spaces with a pattern that matches either space or underscore
    pattern = escaped_name.replace(r'\ ', r'[_ ]')
    # Add an optional "@" at the beginning and allow for case insensitivity
    return f'@?{pattern}'

# Create regex patterns for all airlines
patterns = [create_pattern(airline) for airline in airlines]
keywords = r'\b(?:' + '|'.join(patterns) + r')\b'

# Step 1: Check for mentions of any airline, case-insensitive
test_data['contains_airline'] = test_data['full_text'].str.contains(keywords, case=False, regex=True)

# Step 2: Filter out tweets where contains_airline is True
filtered_data = test_data[~test_data['contains_airline']]

# Step 3: Filter out tweets that are replies to airlines
filtered_data = filtered_data[(filtered_data['replied_tweet_id'] == '') | (~filtered_data['replied_tweet_id'].isin(airlines_id))]
filtered_data = filtered_data[~filtered_data['user_id'].isin(airlines_id)]


# Print counts
print(f"Mentions that CONTAIN AIRLINE: {test_data['contains_airline'].sum()}")
print(f"Non-mentions that DO NOT CONTAIN AIRLINE: {len(test_data) - test_data['contains_airline'].sum()}")

print(len(test_data), 'no of tweets in test_data')
print(len(filtered_data), 'no of tweets in filtered data')

# Display the output columns
print(filtered_data[['tweet_id', 'user_id', 'replied_tweet_id', 'full_text', 'contains_airline']])
# Out:
# Mentions that CONTAIN AIRLINE: 4469547
# Non-mentions that DO NOT CONTAIN AIRLINE: 1678558
# 6148105 no of tweets in test_data
# 1285687 no of tweets in filtered data
#                     tweet_id              user_id     replied_tweet_id  \
# 2        1131172864147808257           3420691215                 None
# 17       1131166315400577024           2383996850                 None
# 18       1131173222039412736           2900385661                 None
# 21       1131118866082480129             30231490                 None
# 25       1131173335545593856            224916583                 None
# ...                      ...                  ...                  ...
# 6148065  1244696446760296448            437502803  1244694218108538881
# 6148069  1244696488455921670            355187133                 None
# 6148072  1244002553349758977            129936509                 None
# 6148081  1244696565203316742  1179195262625026048                 None
# 6148100  1244696703690772485            278698748                 None
#
#                                                  full_text  contains_airline
# 2        RT @bttr_as1: @goody_tracy Here’s a list of so...             False
# 17       Популярная тенденция в 1-м мире. В сериале "Ут...             False
# 18       RT @serg_rubtsov: Популярная тенденция в 1-м м...             False
# 21               Never EVER again will I take a 6am flight             False
# 25       RT @John_Currie: Another 🌅, another 🦅 to  see ...             False
# ...                                                    ...               ...
# 6148065  @rogierspoel @ytekedejong https://t.co/hJrH9mXEBI             False
# 6148069  RT @mikewaghorne: I saw a comment on Facebook ...             False
# 6148072  Grave denuncia de los compatriotas que cumplen...             False
# 6148081  RT @rosiewright99: Today @euronews on #COVIDー1...             False
# 6148100  RT @jfergo86: Me parece a mí o el avión es más...             False
#
# [1285687 rows x 5 columns]

# %%
# Airlines list
airlines = [
    'KLM', 'Lufthansa', 'American Air', 'RyanAir', 'British Airways', 'EasyJet', 
    'Air France', 'Singapore Airlines', 'Qantas', 'Etihad Airways', 'Air Berlin',
    'BritishAirways', 'AirFrance', 'SingaporeAirlines', 'EtihadAirways', 'AirBerlin',
    'AmericanAir', 'VirginAtlantic', 'Virgin Atlantic'
]

# Function to clean mentions not in the airlines list
def clean_mentions(text):
    # Regex pattern to find mentions
    mention_pattern = r'@([A-Za-z0-9_]+)'
    mentions = re.findall(mention_pattern, text)
    
    # Check if each mention is in the airlines list
    valid_mentions = [f"@{mention}" for mention in mentions if mention in airlines]
    
    # Replace invalid mentions in the text
    for mention in mentions:
        if mention not in airlines:
            text = text.replace(f"@{mention}", "")
    
    return text

# Apply the cleaning function to the DataFrame
test_data['cleaned_text'] = test_data['full_text'].apply(clean_mentions)

# Display the original and cleaned tweets
print("Original Tweets:")
print(test_data['full_text'])
print("\nCleaned Tweets:")
print(test_data['cleaned_text'])
# Out:
# Original Tweets:
# 0          La ruta de easyJet entre Londres y Menorca tra...
# 1          @goody_tracy Here’s a list of some of @JonesDa...
# 2          RT @bttr_as1: @goody_tracy Here’s a list of so...
# 3                                           @British_Airways
# 4          Nice change by @AmericanAir. Bikes now pay sta...
#                                  ...
# 6148100    RT @jfergo86: Me parece a mí o el avión es más...
# 6148101    Today’s random pic of the day is the one of Vo...
# 6148102    RT @SchipholWatch: @spbverhagen @markduursma @...
# 6148103    RT @wiltingklaas: Tweede Kamer stemt over vlie...
# 6148104    @easyJet My refund is being process since two ...
# Name: full_text, Length: 6148105, dtype: object
#
# Cleaned Tweets:
# 0          La ruta de easyJet entre Londres y Menorca tra...
# 1           Here’s a list of some of  clients. They shoul...
# 2          RT :  Here’s a list of some of  clients. They ...
# 3
# 4          Nice change by @AmericanAir. Bikes now pay sta...
#                                  ...
# 6148100    RT : Me parece a mí o el avión es más grande q...
# 6148101    Today’s random pic of the day is the one of Vo...
# 6148102    RT :    @KLM   Nog niet aan de orde? Als in: e...
# 6148103    RT : Tweede Kamer stemt over vliegtaks https:/...
# 6148104     My refund is being process since two weeks ag...
# Name: cleaned_text, Length: 6148105, dtype: object

# %%
test_data[['tweet_id', 'cleaned_text']]
# Out:
#                     tweet_id  \
# 0        1131172858951024641
# 1        1130922003702177800
# 2        1131172864147808257
# 3        1131172867985485824
# 4        1131030279278063616
# ...                      ...
# 6148100  1244696703690772485
# 6148101  1244696708983984131
# 6148102  1244696710447800320
# 6148103  1244696713350217728
# 6148104  1244696713765564416
#
#                                               cleaned_text
# 0        La ruta de easyJet entre Londres y Menorca tra...
# 1         Here’s a list of some of  clients. They shoul...
# 2        RT :  Here’s a list of some of  clients. They ...
# 3
# 4        Nice change by @AmericanAir. Bikes now pay sta...
# ...                                                    ...
# 6148100  RT : Me parece a mí o el avión es más grande q...
# 6148101  Today’s random pic of the day is the one of Vo...
# 6148102  RT :    @KLM   Nog niet aan de orde? Als in: e...
# 6148103  RT : Tweede Kamer stemt over vliegtaks https:/...
# 6148104   My refund is being process since two weeks ag...
#
# [6148105 rows x 2 columns]

# %%
def check_given_var(env_var_str: str) -> str:
    """
    Check if the given environment variable is set and return its value.

    Args:
        env_var_str (str): The name of the environment variable to check.

    Returns:
        str: The value of the environment variable.

    Raises:
        AssertionError: If the environment variable is not found.
    """

    env_var = os.getenv(env_var_str)
    assert (
        env_var is not None
    ), f"{env_var_str} is required but not found in environment variables"
    return env_var


def check_env_vars() -> (str, str, str, str):  # type: ignore
    user = check_given_var("DBL_USER")
    database = check_given_var("DBL_DATABASE")
    password = check_given_var("DBL_PASSWORD")
    host = check_given_var("DBL_HOST")
    return user, database, password, host

from mysql.connector import Error
import mysql.connector
from typing import Tuple, List

def connect_to_database(user: str, database: str, password: str, host: str):
    """
    Establish a connection to the database.

    Args:
        user: The database user.
        database: The name of the database.
        password: The password for the database.
        host: The database host.

    Returns:
        A connection object to the MySQL database.
    """
    try:
        connection = mysql.connector.connect(
            user=user, password=password, host=host, database=database
        )
        if connection.is_connected():
            return connection
    except Error as e:
        print(f"Error while connecting to MySQL: {e}")
    return None


def get_batches(df: pd.DataFrame, batch_size: int = 1000) -> List[pd.DataFrame]:
    """
    Split DataFrame into batches of DataFrames with specified batch size.

    Args:
        df: The DataFrame containing tweet data.
        batch_size: The size of each batch.

    Returns:
        A list of DataFrames, each containing a batch of rows.
    """
    return [df.iloc[i : i + batch_size] for i in range(0, len(df), batch_size)]


def update_text(
    batch: Tuple[Tuple[float, str]], user: str, database: str, password: str, host: str
) -> None:
    """
    Create and insert batches of tweets into the database in parallel.

    Args:
        batches_list: Tuple of (sentiment, tweet_id) pairs.
        user: The database user.
        database: The name of the database.
        password: The password for the database.
        host: The database host.
    """
    connection = connect_to_database(user, database, password, host)
    if connection is None:
        return
    cursor = connection.cursor()
    update_query = "UPDATE Tweets SET full_text = %s WHERE tweet_id = %s"
    cursor.executemany(update_query, batch)
    connection.commit()
    cursor.close()
    connection.close()

    print("Sentiment values updated successfully")


import sqlite3
def connect_to_local_database(db_path: str):
    """
    Establish a connection to the local SQLite database.

    Args:
        db_path: The path to the SQLite database file.

    Returns:
        A connection object to the SQLite database.
    """
    try:
        return sqlite3.connect(db_path)
    except sqlite3.Error as e:
        print(f"Error while connecting to SQLite: {e}")
    return None


def update_text_local(
    batch: List[Tuple[str, str]], db_path: str
) -> None:
    """
    Update full_text values for a batch of data in the local SQLite database.

    Args:
        batch: List of (full_text, tweet_id) pairs.
        db_path: The path to the SQLite database file.
    """
    connection = connect_to_local_database(db_path)
    if connection is None:
        return
    try:
        cursor = connection.cursor()
        update_query = "UPDATE Tweets SET full_text = ? WHERE tweet_id = ?"
        cursor.executemany(update_query, batch)
        connection.commit()
    except sqlite3.Error as e:
        print(f"Error updating batch: {e}")
    finally:
        if cursor:
            cursor.close()
        if connection:
            connection.close()

def convert_to_list(df: pd.DataFrame) -> List[List]:
    """
    Convert DataFrame with tweet_id as index to a list of lists containing sentiment and tweet_id.

    Args:
        df: The DataFrame with tweet_id as index and sentiment as a column.

    Returns:
        A list of lists containing tweet_id and sentiment.
    """
    tweet_ids = df.index.to_numpy()
    sentiments = df["cleaned_text"].to_numpy()
    return tuple(zip(sentiments, tweet_ids))

# %%
to_load = test_data[['tweet_id', 'cleaned_text']].set_index("tweet_id")

# %%
data_batches = get_batches(to_load, 10_000)

# %%
convert_to_list(data_batches[0])
# Out:
# (('La ruta de easyJet entre Londres y Menorca transporta a más de 19.000 pasajeros en un año https://t.co/Rqy606KVna https://t.co/buWgtqYwCD',
#   '1131172858951024641'),
#  (' Here’s a list of some of  clients. They should know Jones Day encouraged McGann to break the law:\n \n@AmericanAir \n {surprise face}\n\n \n\n \n \n \n \n \n\nMore to come. Please RT',
#   '1130922003702177800'),
#  ('RT :  Here’s a list of some of  clients. They should know Jones Day encouraged McGann to break the law:\n…',
#   '1131172864147808257'),
#  ('', '1131172867985485824'),
#  ('Nice change by @AmericanAir. Bikes now pay standard checked bag fees. 👍 made a similar change 2 years ago. \n\nYour turn  https://t.co/w4pZcSHVwX',
#   '1131030279278063616'),
#  ('RT : Nice change by @AmericanAir. Bikes now pay standard checked bag fees. 👍 made a similar change 2 years ago. \n\nYo…',
#   '1131172909463027720'),
#  ('BREAKING:-\nKLM to fly 3x weekly btw  and  from winter schedule 2018/19 using Boeing 787-9 aircraft.\n  ',
#   '1131170442809565190'),
#  ('RT : BREAKING:-\nKLM to fly 3x weekly btw  and  from winter schedule 2018/19 using Boeing 787-9 aircraft…',
#   '1131172975682605058'),
#  ('EasyJet was on a slippery slope when it charged for skis - https://t.co/SOI36Thhbf #GoogleAlerts',
#   '1131173010235375617'),
#  ('Thanks  I really needed the extra 2 hour delay on the flight today with everyone sat on board...',
#   '1131173010508062721'),
#  (' It is impossible to get in contact with you by using that e-mail address. So there is no claim yet which I can follow on that damage luggage website. So what to do?',
#  (' can I add luggage fees to a flight that’s already booked or do I need to pay excess rate at the airport? Still weeks to the flight in question',
#   '1131173345918148609'),
#  (" We appreciate your feedback and we'll ensure it's passed on. Can you let us know where you were when the music was playing? Steph",
#   '1131173353291767810'),
#  ('  そんな感じ(ﾉ∀｀笑)\nとくにKLMの機体が好き😘', '1131173383163355137'),
#  ('Extrañas @AmericanAir ?? https://t.co/AeMbW3r7O5', '1131164515163410432'),
#  ('Para nada... I love ', '1131173401895350273'),
#  ('Due to a power outage at Manchester Airport affecting all airlines we have cancelled a small number of flights. All customers have been notified, we apologize for these cancellations which are outside of our control. Click here for more flight updates: https://t.co/4FdQmbbGC9.',
#   '1130217749064691732'),
#  ('Hi  and what about passengers delayed BEFORE the flight was due to take off to Manchester and are still denied compensation? https://t.co/fptE5iQo2o',
#   '1131171392991506432'),
#  ('RT : Hi  and what about passengers delayed BEFORE the flight was due to take off to Manchester and are still denied co…',
#   '1131173426826231808'),
#  (" Flights shocking to tell me that I'm not entitled to a refund due to the fact the seats I paid for were never available?\n#consumerrights ?",
#   '1131169807171235840'),
#  ("RT :  Flights shocking to tell me that I'm not entitled to a refund due to the fact the seats I paid for were ne…",
#   '1131173456597405704'),
#  ('Boeing 737 de @AmericanAir\n\n#boeing737 #avgeek #planespotting #aviationphotography\n#aviationdaily #aviationlovers  https://t.co/lXTC4TQgpz',
#   '1131173455473201153'),
#  (' Oh no! Please can you drop us a DM with your details so we can help you with this? Ems https://t.co/L1epyfzysM',
#   '1131173469339693057'),
#  ('A team of programmers from Qantas talking about app development to  students. What they do, how they got there. https://t.co/LET9NTXted',
#   '1131082908708425728'),
#  ('Thanks for having us  . It was a pleasure.  https://t.co/dsSPgr7pEu',
#   '1131150633740918785'),
#  ('RT : Thanks for having us  . It was a pleasure.  https://t.co/dsSPgr7pEu',
#   '1131173508237545477'),
#  ('    @AmericanAir          Outstanding!  Thank you Tracy.  This is just what we need.  Go to the source of Jones Day money!!',
#   '1131173537388093441'),
#  (' Here’s a list of some of  clients. They should know Jones Day encouraged McGann to break the law:\n \n@AmericanAir \n {surprise face}\n\n \n\n \n \n \n \n \n\nMore to come. Please RT',
#   '1130939919772209152'),
#  ('RT :  Here’s a list of some of  clients. They should know Jones Day encouraged McGann to break the law:\n…',
#   '1131173565213155329'),
#  (' Hola Abstrusu. Le pido que por favor me escriba en castellano para poder atenderle mejor ;-). Sin embargo, por lo que puede entender ¿su vuelo ha sufrido un retraso? Le pido que me escriba un DM contándome más detalles para poderle ayudar mejor. Saludos, Tiziana😉',
#   '1131087622661726208'),
#  ('RT :  Hola Abstrusu. Le pido que por favor me escriba en castellano para poder atenderle mejor ;-). Sin embargo, por lo que…',
#   '1131173576873250816'),
#  ('Op dit moment vliegt #KLM vlucht KLM51K richting het zuiden op een hoogte van 4.3km over #Barendrecht.',
#   '1131173623488761857'),
#  ('  Questo è il colmo: siccome l’aeroporto è stato chiuso per le frecce tricolori poi dopo c’è stato l’errore. Se fossimo un Paese normale dovrebbe arrivare una multa salatissima a Ryanair e allo scalo e un risarcimento al passeggero. Ma siamo in Italia, vedremo... #poverapatria',
#   '1131173947704303618'),
#  ('Ryanair Boeing 737NG 8AS/W (EI-FIM, #4CA53E) at 36000 ft OTT #RyanHQ',
#   '1131173955342163968'),
#  ('.@KLM will fly Amsterdam-Bangalore now that Jet Airways has ceased operating the route. [NL]   via  \nhttps://t.co/Iv90vIlE1t',
#   '1131165117129863168'),
#  ('RT : .@KLM will fly Amsterdam-Bangalore now that Jet Airways has ceased operating the route. [NL]   via …',
#   '1131173974342193152'),
#  ('@KLM to launch thrice weekly service from Amsterdam to   using a #B787 according to this news report. As reported AF-KLM-VS-DL have lost valuable feed from India with 9W suspending operations. \nH/t  for the article.\n\nhttps://t.co/bmb4W1feUG',
#   '1131165988781608961'),
#  ('RT : @KLM to launch thrice weekly service from Amsterdam to   using a #B787 according to this news report. As rep…',
#   '1131173996337098752'),
#  ('RT : BREAKING:-\nKLM to fly 3x weekly btw  and  from winter schedule 2018/19 using Boeing 787-9 aircraft…',
#   '1131173999197663232'),
#  ('@AmericanAir flight delays this morning due to mechanical problems. A hassle, but glad to be on the ground while they fix the problems. #beingproductive',
#   '1131174000695160837'),
#  ("  It's worth it 2 c me", '1131174008811118597'),
#  ('Thank you  for showing me around your Airbus A380  / First Class Suite . I enjoyed the experience 😁 i will surely return https://t.co/seO5Oq6F85',
#   '1130948019095048192'),
#  ('RT : Thank you  for showing me around your Airbus A380  / First Class Suite . I enjoyed the experience 😁 i will sure…',
#   '1131174024900481024'),
#  ('Calling all athletes 🚴🏾\u200d♀️ and musicians 🎷: \n\nWhether a novice or pro, you can now travel with your sports or music equipment without paying extra oversize fees!\nhttps://t.co/MMQyN0V6kf',
#   '1130940092737052672'),
#  ('Under this great new policy we can now carry our curling stones with us 🥌🥌🥌🥌🥌 #handy #whatweightlimit https://t.co/PgCyFFQwK6',
#   '1131168734905798657'),
#  ('RT : Under this great new policy we can now carry our curling stones with us 🥌🥌🥌🥌🥌 #handy #whatweightlimit https://t.co/PgCy…',
#   '1131174063190282240'),
#  ('Y como si fuera poco Ryanair cancela 2 rutas para el invierno con Londres y East Midlands. Ya son 7 las rutas internacionales perdidas y 3 la aerolíneas a pesar del dinero tirado en promoción y autobuses. Con lo bien que iban en San Javier.  A más despilfarro menos turistas.',
#   '1131155696265957377'),
#  ('RT : Y como si fuera poco Ryanair cancela 2 rutas para el invierno con Londres y East Midlands. Ya son 7 las rutas internacionales…',
#   '1131174094513299456'),
#  ('Este nuevo #acuerdocolectivo no solo quiere asegurar unas buenas condiciones laborales y un entorno laboral de calidad para  https://t.co/kfiqWLeR95 vía ',
#   '1131174098510503936'),
#  (' Here’s a list of some of  clients. They should know Jones Day encouraged McGann to break the law:\n \n@AmericanAir \n {surprise face}\n\n \n\n \n \n \n \n \n\nMore to come. Please RT',
#   '1131006039627722752'),
#  ('RT :  Here’s a list of some of  clients. They should know Jones Day encouraged McGann to break the law:\n…',
#   '1131174099974328322'),
#  ('RT : Nice change by @AmericanAir. Bikes now pay standard checked bag fees. 👍 made a similar change 2 years ago. \n\nYo…',
#   '1091024872258572289'),
#  ('RT :     necesitamos pasajes para llevar ayuda a #Cuba  desde Barcelona, Madrid, Alemania,…',
#   '1131174543941394432'),
#  ('Sources say @EtihadAirways, Hindujas &amp; AdiGro may join forces to rescue  https://t.co/9ClJwnzdVo',
#   '1131154847632203776'),
#  ('RT : Sources say @EtihadAirways, Hindujas &amp; AdiGro may join forces to rescue  https://t.co/9ClJwnzdVo',
#   '1131174581182423041'),
#  ('Ads on the tube in the London Underground highlight BA’s role in forcibly deporting refugees this Christmas.  https://t.co/Jw6V26P7oA',
#   '1131174585565630464'),
#  ('RT : Thank you  for showing me around your Airbus A380  / First Class Suite . I enjoyed the experience 😁 i will sure…',
#   '1131174585892839424'),
#  (" Send us your booking reference via DM along with as much info as possible so we can take a closer look. We'll also need you to confirm your full name and contact details. We may need to ask you a few more questions for data protection. Tony",
#   '1131174604679127041'),
#  ('VH-EBH - ‘Hunter Valley’ as @Qantas 642 from Perth on short final for runway 25 passing over General Holmes Dr and the  sign (not even sure if it’s still there!) Aircraft is now with the  as A39-006 after conversion in Madrid May 2015 - July 2017! https://t.co/leHg4nHJcW',
#   '1131170389852213248'),
#  ('RT : VH-EBH - ‘Hunter Valley’ as @Qantas 642 from Perth on short final for runway 25 passing over General Holmes Dr and the …',
#   '1131174612983615489'),
#  (' Hello Have DM’d booking ref etc! done, thank you x',
#   '1131174619224924160'),
#  (' Found #OlderandWider podcast whilst waiting for a delayed easyjet flight. It dealt beautifully with my anger issues Jenny, and I now have the delight of catching up with all the back episodes.....enjoying it immensely, thanks ladies x',
#   '1131174646357876736'),
#  (' Gracias por volver a escribir Abstrusu. Debo informarle sin embargo que solo podemos responder a los mensajes en castellano. En caso que me necesite de nuevo, no dude en volver a contactarme. Saludos y feliz día. Tiziana',
#   '1131174648580845568'),
#  ("RT : @AmericanAir updates baggage policy on sports equipment, still clearly doesn't understand #curling.\n https://t.co/es0ix…",
#   '1131174661348352000'),
#  ('Every time I come through  I’m reminded why I try to avoid this pit. #MIA #YouStillSuck @AmericanAir you REALLY suck',
#   '1131174676376563717'),
#  (' @KLM Thanks Dan', '1131174682525351937'),
#  ('Ryanair Boeing 737NG 8AS/W (EI-FRG, #4CA658) at 36000 ft heading north east bound OTT south east of #RyanHQ',
#   '1131174684224040960'),
#  ('영국항공과 함께 영국과 유럽으로 로맨틱한 휴가를 떠나보세요.', '1129335940906999810'),
#  ('RT : 영국항공과 함께 영국과 유럽으로 로맨틱한 휴가를 떠나보세요.', '1131174712304791552'),
#  ('A new adventure is taking flight. Where will yours be? #Etihad787 https://t.co/gTR0xqbJdl',
#   '1131130306101219328'),
#  ('Did you mean  ?', '1131174735813832704'),
#  (' @AmericanAir Contact the better business bureau. I’m sure they care about their ratings. Hit them where it hurt since they don’t care about what’s important to u.',
#   '1131174754784829442'),
#  ('Can always count on @AmericanAir to help you miss a wedding #delayed #customerservice #neverfly',
#   '1131174768114323458'),
#  ("On arrive fons’ comme Ja', tous high,\xa0plane comme Lufthansa\nTellement vif, Osirus Jack man là pour les sous comme un tellement Juif (kippa)",
#  ("RT : Hi . You've refused to engage on social media over your unpaid, unadvertised ident with @AmericanAir &amp; repea…",
#   '1131175424518774784'),
#  ('British airways flight review - London to Tallinn  https://t.co/U6G2jqTa1a  #flight #review https://t.co/KqS5NmVYhp',
#   '1131175483041824769'),
#  ('Aprovada a MP que autoriza a entrada 100% de capital estrangeiro no mercado aéreo. Na prática, além de Gol, Latam e Azul, poderemos ter voos domésticos operados por empresas como American, United, Air France, Delta, Copa, KLM, Lufthansa, entre outras. O Brasil avança.',
#   '1131024558289506305'),
#  ('RT : Aprovada a MP que autoriza a entrada 100% de capital estrangeiro no mercado aéreo. Na prática, além de Gol, Latam e Azul,…',
#   '1131175518064271360'),
#  (' お？\n今の状況。\nKLMの令和セールちょい高くなってきた https://t.co/4dFVuDQuyu',
#   '1131175528004644864'),
#  ('   @VirginAtlantic I better win ❤️', '1131175541200117761'),
#  (' Hi, may we have DM  the booking reference number to check?Meri https://t.co/lJbiiehJxU',
#   '1131175566659510273'),
#  (" That's certainly annoying. Unfortunately, we can't do anything with seats as it's now within 24 hours of your departure. Is your flight operated by American Airlines? Liz",
#   '1131175566625955842'),
#  ('that was not a clever move! You should behave like the president and vice-president of the US and never be on the same flight! Too much PV knowledge at stake! https://t.co/15IswXhICN',
#   '1131172497079066624'),
#  ('I will inform KLM about this serious requirement of Pearl related travel 😂 but how to handle this when we all will meet for the Pearl PV Seminar in Malta in October? https://t.co/chSl33vmYu ',
#   '1131175578869092353'),
#  (' You bet!', '1131175633344782336'),
#  ('.@VirginAtlantic ’s Mumbai-Heathrow flight to make available 26 tonnes of #Cargo capacity\n\n#aviation #AvGeek \nhttps://t.co/lruUK8iPd4',
#   '1131175659223437312'),
#  ('5* Lufthansa SALE: Cheap flights from Germany to many European cities and vice-versa from only €88! https://t.co/1eSv4HPhni',
#   '1131175711287517186'),
#  ('La strategia di Ryanair: guadagnare meno per distruggere i concorrenti\xa0 https://t.co/ssWxxgKWk8',
#   '1131175768686497794'),
#  ('Un total de 19.000 passatgers han volat entre Maó i Londres amb Easyjet en el darrer any https://t.co/6nkbeS7yNB',
#   '1131175793214861314'),
#  (' Ok, sent reference', '1131175802979135491'),
#  ('RT : .@VirginAtlantic ’s Mumbai-Heathrow flight to make available 26 tonnes of #Cargo capacity\n\n#aviation #AvGeek \nhttps://t.co/l…',
#   '1131175807903326208'),
#  ('The new @AmericanAir flight to Los Angeles is a vital link for the #Louisville business community and a time saver when traveling to the west coast or beyond! #Flylouisville https://t.co/GWFKonDk2g',
#   '1130901697348427777'),
#  ('This flight opens new doors when it comes to attracting investment, creating new jobs and increasing tourism traffic to our community.',
#   '1131175822977634304'),
#  ('Ryanair Sun Boeing 737NG 800/W (SP-RSU, #48C233) as flight #RYR3ZP at 36000 ft heading south west bound OTT east of #RyanHQ',
#   '1131175865323278337'),
#  ("Moment police bundle raging easyJet passenger off flight at Gatwick after he 'locked himself in loos during landing' https://t.co/bEhCO48zOn",
#   '1131175888769433602'),
#  ('@AmericanAir What about my shuffleboard cue?', '1131175905173417984'),
#  (" That certainly is annoying. Hopefully, you're on your way now and we're sorry for any inconvenience caused. We hope you enjoy the rest of your day! Liz",
#   '1131175995321520128'),
#  ('@Qantas Trying to join the Qantas Club but technical difficulties at your end preventing progress. Would be great if you had an estimated time this would be fixed.',
#   '1131176007510110210'),
#  (' Sorry for the inconvenience, if you wish you may submit a complaint here: https://t.co/uBey6h6Srp Ana',
#   '1131176025336025089'),
#  ('@AmericanAir you going to cover my rental car and gas for having to drive to my connecting airport after canceling my flight.  Worst airline ever.  Wont even talk to customers.  Tell us to email support.',
#   '1131176087168225281'),
#  (". vola la ruta entre Menorca i Londres amb un mínim d'una freqüència diària durant la temporada d'estiu i dues freqüències setmanals en la temporada d'hivern https://t.co/0ZZGs5gOzd",
#   '1131176088950968322'),
#  ('Alabama Public Television says it won\'t air an episode of the children\'s show "Arthur" that featured a same-sex marriage https://t.co/SJIVzCMOoZ',
#   '1130885986353864704'),
#  ('If you guys need help with honeymoon plans, just get in touch!\n#Arthur #VirginHoneymoons',
#   '1131176095515062272'),
#  (' Yes it is. I do not want to check in tomorrow and the 5 of us be split across the plane',
#   '1131176096005861376'),
#  ('This #digital screen synchronizes with the #planes that fly over it\n\nby \n\n              https://t.co/Rg9FDm5sq1',
#   '1131075648171249669'),
#  ('RT : This #digital screen synchronizes with the #planes that fly over it\n\nby \n\n  …',
#   '1131176151030935552'),
#  (' @AmericanAir Oh it took off on time girl just the 4am awake 430 Uber all the locals in the airport https://t.co/QOuIikQH7F',
#   '1131176158647717889'),
#  ('RT @EtihadAirways: A new adventure is taking flight. Where will yours be? #Etihad787 https://t.co/gTR0xqbJdl',
#   '1131176161403330561'),
#  (' Hello SQ why we cannot find SQ codeshared flights operated by  in your booking engine. Earlier the inventory was visible but not now',
#   '1131176200020217857'),
#  ('RT @VirginAtlantic: If you guys need help with honeymoon plans, just get in touch!\n#Arthur #VirginHoneymoons https://t.co/HHqeUJTwJL',
#   '1131176257926979584'),
#  (' EasyJet has the orange franchise... https://t.co/lSvxZ9Sxh6',
#   '1131176286804742145'),
#  ('@VirginAtlantic Free money or loans?', '1131176383835721729'),
#  ('Dienstbeginn für den neuen Sitz von #Lufthansa, #Swiss und #AustrianAirlines https://t.co/bVSgLt5NhZ',
#   '1131151954493825024'),
#  ('RT : Dienstbeginn für den neuen Sitz von #Lufthansa, #Swiss und #AustrianAirlines https://t.co/bVSgLt5NhZ',
#   '1131176416316481536'),
#  ('@VirginAtlantic https://t.co/OVNDQ0kR45', '1131176413183262720'),
#  ("RT : Moment police bundle raging easyJet passenger off flight at Gatwick after he 'locked himself in loos during landing' https…",
#   '1131176428211384322'),
#  ('RT : ✐似顔絵サロン✐\n追加オプション｢美少年化｣について\n美少女もオジサマもみんな美少年に変身させます❇本人に似ているかはさて置いて劇的ビフォーアフターをお楽しみください😌どんな美少年になるか基本お任せですが何かご希望があれば仰ってくださいね✌サンプル提供は…',
#   '1131176431822680065'),
#  ('5* Lufthansa SALE: Cheap flights from Germany to many European cities and vice-versa from only €88! https://t.co/3496GmCYEI #CheapFlights #Travel #Deal',
#   '1131176442266640392'),
#  ('  has these made for myself using my pics! Coffee times just got a whole lot better!! https://t.co/LDuOjS7jqV',
#   '1131176457059938304'),
#  (' hello - we\'re currently in France, returning to Southampton on BE3036 (from Paris CDG) tomorrow.  Online check-in (redirect to Airfrance) says "not available". Do we have to do online check-in, or can we sort it out at airport? Thanks!',
#   '1131176476328517633'),
#  (" So you've paid to rebook a new flight to Oslo but your original ticket has been changed free of charge, is that correct? Please follow up with a DM, so we can clear security and see if we can help with this. Pip",
#   '1131176479180693512'),
#  (' If you are in communication with our Customer Relations team, you can share your additional comments by replying to their email.',
#   '1131176485568557056'),
#  (' @AmericanAir Yes all that!!! then imagine having to sit in the airport all morning 😭 I am depressed',
#   '1131176488441667584'),
#  ('Atterrati. Si accorge che si trova a Bari e non a Cagliari. 😂😂 #Ryanair volo Pisa - Bari https://t.co/yIHTk6GrUs',
#   '1130398491619090433'),
#  ('RT : Atterrati. Si accorge che si trova a Bari e non a Cagliari. 😂😂 #Ryanair volo Pisa - Bari https://t.co/yIHTk6GrUs',
#   '1131176506087157760'),
#  ('Ryanair Boeing 737NG 8AS/W (EI-DAG, #4CA1B8) as flight #RYR93KC at 11200 ft heading north bound OTT south east of #RyanHQ',
#   '1131176515125809153'),
#  ('@AmericanAir  what is this ... cant access your site\n\na n error occurred while processing your request.\nReference #97.5f89fea5.1558528327.f6a9662',
#   '1131176584583536641'),
#  ('Ryanair Boeing 737NG 8AS/W (EI-EGA, #4CA7B6) as flight #RYR14RR at 33825 ft heading west bound OTT east of #RyanHQ',
#   '1131176596474355712'),
#  ('KLM vliegt na wegvallen Jet Airways zelf op Bangalore https://t.co/7DIqcguyxe https://t.co/6d9AdCtSYt',
#   '1131159789348671489'),
#  ('Waar @KLM de slots vandaan haalt is (nog) niet bekend..',
#   '1131176632402812930'),
#  (' @AmericanAir  Congratulations to your brother. And, to you. 😊',
#   '1131176652757766146'),
#  (' Yes that’s exactly right. I’ll DM you now.', '1131176706759385088'),
#  ('RT : Aprovada a MP que autoriza a entrada 100% de capital estrangeiro no mercado aéreo. Na prática, além de Gol, Latam e Azul,…',
#   '1131176707141058562'),
#  ('Would people have an issue over Baku if there were direct flights from London with easyJet for £85.\n\nFantastic city and deserve as much right to host a final as Madrid or London. \n\nIf they can host an F1 event they can cope with a Europa league final https://t.co/56RIF53EzS',
#   '1131130906851381248'),
#  ('RT : Would people have an issue over Baku if there were direct flights from London with easyJet for £85.\n\nFantastic city and…',
#   '1131176719421976577'),
#  ('@Qantas On The qantas website', '1131176727575535616'),
#  ('Congratulations to our 14 lucky week 6 winners, who have all won return flights for two with @EtihadAirways.\n\n#FuelAndFly\n#ForLifesJourney\n#ADNOCDistribution https://t.co/d5QKZuZP3X',
#   '1131156967127437312'),
#  ('RT : Congratulations to our 14 lucky week 6 winners, who have all won return flights for two with @EtihadAirways.\n\n#FuelAndFly\n#F…',
#   '1131176747863556096'),
#  ('Ecco la seconda parte. #Ryanair #pisa #bari https://t.co/8QXmpbU18U',
#   '1130552258003918848'),
#  ('Why are the  planes going to Accra filthy and old? This is a waste of money. https://t.co/PPBIzkbCUO',
#   '1131177391005601793'),
#  ("Hey @Qantas how do I claim missing QFF miles from an Airbnb booking? It's been about 10wks since I checked out 😡",
#   '1131177542633762817'),
#  ('La cascada interior más alta del mundo está en el aeropuerto Changi de Singapur.  https://t.co/EXYjn460cm https://t.co/pOKTlMBAH4',
#   '1131138263731855360'),
#  ('RT : La cascada interior más alta del mundo está en el aeropuerto Changi de Singapur.  https://t.co/EXYjn460cm ht…',
#   '1131177570769223682'),
#  ('Hey @AmericanAir - how do I remove the “Ask Siri for your flight details” from the app? I don’t see it the settings. Thank you! https://t.co/3AzAbLtIy4',
#   '1131177590490882049'),
#  ("✈️ How does the world's biggest airline manage the grounding of 115 flights a day because of a safety crisis?\n\nVasu Raja of @AmericanAir has been explaining its #Boeing737Max problems to  \n\n#aviation #airplanes #avgeeks #Boeing737 #Boeing #flying #travel https://t.co/xYHvYeJpcB",
#   '1131078417380761600'),
#  ("RT : ✈️ How does the world's biggest airline manage the grounding of 115 flights a day because of a safety crisis?\n\nVasu Ra…",
#   '1131177619100246016'),
#  ('More of  clients. Clients should know Jones Day encouraged McGann to break the law:\n \n@AmericanAir \n {surprise face}\n\n \n\n \n \n \n \n \n\nMore to come. Please RT.',
#   '1131163587005812741'),
#  ('RT : More of  clients. Clients should know Jones Day encouraged McGann to break the law:\n \n@AmericanAir \n…',
#   '1131177658690129920'),
#  ('   Tall boy brethren unite!', '1131177661311672320'),
#  (' Similar to what Emirates offers when transiting dxb.  care to reply??',
#   '1131177673764610048'),
#  ('5* Lufthansa SALE: Cheap flights from Germany to many European cities and vice-versa from only €88! https://t.co/TKdMhHgNjT',
#   '1131177695759478786'),
#  ('RT : Why are the  planes going to Accra filthy and old? This is a waste of money. https://t.co/PPBIzkbCUO',
#   '1131177697391063040'),
#  ('RT : Aprovada a MP que autoriza a entrada 100% de capital estrangeiro no mercado aéreo. Na prática, além de Gol, Latam e Azul,…',
#   '1131177752558788608'),
#  (' @AmericanAir Luckyyyy', '1131177805734076416'),
#  (' @AmericanAir Would’ve been really funny if they threw the ripped up pieces at your chest and the gate agent did a follow through after',
#   '1131177807273349121'),
#  ('Hey, ! The BA website advertises that returns from Nashville BNA are "from" £249 for a certain day, yet prices start from £307.\n\nBut that\'s a £58 difference... https://t.co/lkkzoxmVXc',
#   '1131177834175750144'),
#  (' You can find contact details here: https://t.co/eZHtMInQRK. Just remember to change your country to Saudi Arabia. Liz',
#   '1131177862101426177'),
#  (". Dahl and Newman's mixes are now live in the air aboard  long haul flights this May as our residency in the sky continues with . https://t.co/zI6tUSVGOc",
#   '1130865434624790528'),
#  ("RT : . Dahl and Newman's mixes are now live in the air aboard  long haul flights this May as our re…",
#   '1131177866010533888'),
#  ('Wonder whether this is with the use of old Jet Airways slots, KLM slots... If the later, then it’ll mean the reduction of service somewhere else on the KLM network. https://t.co/2E6TRQferw',
#   '1131170269291266049'),
#  ('RT : Wonder whether this is with the use of old Jet Airways slots, KLM slots... If the later, then it’ll mean the reduction…',
#   '1131177866861801478'),
#   '1131187797765890051'),
#  ('   @AmericanAir    ', '1131187820389732353'),
#  ('RT :  마음과 마음을 이어 모두를 웃게 해주는 평화여행길 귀하신 님과함께  하고싶네요....\n#피스레터계평화선언문6주년 기념식 및 #평화걷기\n#525 #DPCW지지 \n5월 25일 오전10시30분 유…',
#   '1131187820347813888'),
#  ('Ryanair says it is "Europe\'s greenest, cleanest airline." But its entire business model is challenged by climate change https://t.co/gRoqDNIygg',
#   '1131187821161721859'),
#  (' Hi. I need some help with baggage booking for my flight. Can you please open a DM line?',
#   '1131187849670352896'),
#  ("RT : 'o jornalista que se prove ter participado na conceção ou apresentação de conteúdos patrocinados, publicados em órgão de comun…",
#   '1131187893739884549'),
#  ('@Qantas And last time I gave this info... nothing.\nI want a written guarantee that my original request will be followed through. I’m sick of trying &amp; I won’t do it again until I’m promised. Im sick of being ignored',
#   '1131187900576518144'),
#  ('  Upgrade? On Conner 😂', '1131187906230542336'),
#  (' @AmericanAir American is an absolute shit show of an airline, every single time.',
#   '1131187925574668288'),
#  ('RT : Já vi várias noticias deste género mas nunca vi uma viagem a este preço, nem conheço ninguém que tenha comprado uma. htt…',
#   '1131187932335882240'),
#  ('RT :  Here’s a list of some of  clients. They should know Jones Day encouraged McGann to break the law:\n…',
#   '1131187939675820033'),
#  ('I left this handmade doll on  flght FR7197 PMI to HAM on Sat 18. May. Is there any hope of getting it back? https://t.co/KYdMLJZBXY',
#   '1131187940737134593'),
#  (' We understand that you would prefer to have your baggage with you on board. Our colleagues at the airport may request that your hand baggage will be transported in the hold, due to the available space and the amount of hand baggage on board, for example.&gt;&gt;&gt;',
#   '1131187978771025921'),
#  (' Ryanair would have charged you extra for the filling...',
#   '1131187983867142146'),
#  (' @KLM Happy Birthday Lady Cakes 🎉🎉🎉', '1131187998157094912'),
#  (' Con el fin de evitar errores nosotros volvemos a redirigirte al centro de llamadas local debido a que ha sido por esa via donde se han hecho las ultimas modificaciones en tu pasaje.',
#   '1131188028528107521'),
#  (' Hi, direct message. Private one. Tere', '1131188028561645568'),
#  ("RT : 'o jornalista que se prove ter participado na conceção ou apresentação de conteúdos patrocinados, publicados em órgão de comun…",
#   '1131188037113778177'),
#  (' We do understand that some passengers do not like this, so we usually look for volunteers first. In case we have no (sufficient) volunteers, it is possible that passengers travelling with large bags (which do not fit under the seats) are designated.&gt;&gt;&gt;',
#   '1131188089328734209'),
#  ('RT : Nice change by @AmericanAir. Bikes now pay standard checked bag fees. 👍 made a similar change 2 years ago. \n\nYo…',
#   '1131188089802567680'),
#  ('RT : Gentile passeggero furibondo del volo Ryanair Pisa-Bari, ha quasi tutta la mia solidarietà. \n\n“Un eroe del nostro tempo”, #I…',
#   '1131188094173143042'),
#  ('RT : Gentile passeggero furibondo del volo Ryanair Pisa-Bari, ha quasi tutta la mia solidarietà. \n\n“Un eroe del nostro tempo”, #I…',
#   '1131188140948021248'),
#  ('Cabin Attendant KLM\xa0Cityhopper https://t.co/SDWJRYge1F',
#   '1131188173118345216'),
#  ('The first Air France 747 to arrive at YYZ May 1976 https://t.co/aykVXPjtC3 #pearsonpast #avgeek    https://t.co/sQisj2E6Kk',
#   '1131017520788496386'),
#  ('RT : The first Air France 747 to arrive at YYZ May 1976 https://t.co/aykVXPjtC3 #pearsonpast #avgeek   @…',
#   '1131188248968093697'),
#  ('We are now two hours inside the plane, with no takeoff, no one tell us with certainty what is going on. Problem with the fuel load and now a power reset. Fix whatever you need, but with us down the plane 🙏🏻. Flight #AF179 Mexico City-Paris   ',
#   '1131044887950966784'),
#  ('RT : We are now two hours inside the plane, with no takeoff, no one tell us with certainty what is going on. Problem with th…',
#   '1131188250733928449'),
#  ('Ryanair Boeing 737NG 8AS/W (EI-EMM, #4CA855) as flight #RYR17HT at 33400 ft heading south east bound OTT west of #RyanHQ',
#   '1131188262440247296'),
#  ('@AmericanAir ', '1131188266382704640'),
#  ("RT : #AirFrance et #AirFranceStudio ravis de soutenir l'aventure #JeFilme2019 ! Félicitations aux élèves du lycée Darchicourt d'…",
#   '1131188283537580034'),
#  (' Hoi Amber, we adviseren je om contact op te nemen met de Lost&amp;Found afdeling van het vliegveld van aankomst. We hopen dat je het snel terugvindt!',
#   '1131188287803142145'),
#  ('🙏🏿🙏🏿🙏🏿God I see what you fit do https://t.co/RLqdQq8lRl',
#   '1131133985856327680'),
#  ('RT : 🙏🏿🙏🏿🙏🏿God I see what you fit do https://t.co/RLqdQq8lRl',
#   '1131188298469322753'),
#  (' Hey, Robin. Which lounge were you in? Please also DM your booking info, passport number and expiry date. Steph https://t.co/L1epyfzysM',
#   '1131188299857649665'),
#  (' Keys, medicines or your laptop may always be taken from this baggage to be carried with you. On our website you can find more information about the check in of hand luggage: https://t.co/chXrkC5PV4. Furthermore, please know that you cannot track your check-in baggage online.&lt;&lt;&lt;',
#   '1131188303821180928'),
#  ('RT : 영국항공과 함께 영국과 유럽으로 로맨틱한 휴가를 떠나보세요.', '1131188334984740870'),
#  ('  Ya ya aq klm', '1131188340001140737'),
#  (' Hi, please contact us DM in order to assist you better, \nIrene',
#   '1131188370988773377'),
#  ('       @KLM Me and my Friends are at the main entrance https://t.co/ouSFjSlWow',
#   '1131188385450737665'),
#  ('Hi  on your app, flight 464 is listed as “on time”. It has not left yet. Any update on this?',
#   '1131188415410651136'),
#  (' OK, it is now another week that has passed and nothing. I have yet to even be reimbursed the $98.00 I paid for the selected seats and that is since April 23. At this point I am not at all impressed with  customer service department. I need to speak to someone PLEASE.',
#   '1131188453213761537'),
#  ('Não eras tu que querias voar?   não encontras melhor preço 👌 podes levar a família , o cão , o gato e o periquito . Cabem todos . Aínda há festa na terra da batota 😂😂',
#   '1131188455822827521'),
#  ('  Hi, we are sorry. Contact us via DM in order to search for your reservation.\nTere',
#   '1131188498961195008'),
#  ('RT : Aprovada a MP que autoriza a entrada 100% de capital estrangeiro no mercado aéreo. Na prática, além de Gol, Latam e Azul,…',
#   '1131188501272301571'),
#  (' Hi BA :). Do you allow plane pals on your flights? https://t.co/NqfQ9F2MgT',
#   '1131188502392135680'),
#  ("  Yeah, it's super easy to add niche/demography specific tags to subs. Don't send people group-specific things if you don't know they're part of that group.",
#   '1131188533119639552'),
#  (" Let's see how we can help. Drop us a DM with as much info as possible and remember to include your reference number and full contact details. We may need to confirm you are who you say you are by asking a couple more questions depending on what you need help with. Kevin B https://t.co/L1epyfzysM",
#   '1131188540187004928'),
#  ('RT : "Le rôle des femmes dirigeantes est d’ouvrir la voie, de donner envie d’oser et de susciter des vocations.", selon …',
#   '1131188597543931905'),
#  ('RT : I gave this a lot of thought on the plane.  I sincerely hope the reason @AmericanAir ripped up  ticket i…',
#   '1131188630456815616'),
#  (' agrees: she would never buy all extras through 1 app and never installs apps with no added value, not even an #aviation app - e.g. so far her KLM #AI customer journey on social media feels worse than before  ...  #multimobility or autonomous super #planner?\n\n#EFTLondon https://t.co/uurKXwp8Xe',
#   '1131188635137650688'),
#  (' done', '1131188643580776448'),
#  ('RT : KLM wil zelf ook van vluchten naar Brussel af https://t.co/9BB10gPNqh https://t.co/jhzqxfNDaP',
#   '1131188677206532096'),
#  (' Big shoutout to these hard working managers in Charlotte for helping us board our flight to Dallas while waiting on the crew to arrive from another flight. https://t.co/tdZ4UG58ZF',
#   '1131188679270125568'),
#  ("  Imagine I was a woman who wants kids but can't have them. Painful.",
#   '1131188721334796288'),
#  ('RT : Why are the  planes going to Accra filthy and old? This is a waste of money. https://t.co/PPBIzkbCUO',
#   '1131188758580219905'),
#  (' @EtihadAirways             Paid for my card 1 month ago still not received it.',
#   '1131188789458743297'),
#  (' Done! Waiting for your reply. \nTere', '1131188811139112960'),
#  (" That's a little strange, I've tried to replicate this and it comes up with Frankfurt first. What browser are you using?  Tony",
#   '1131188826632785920'),
#  ('RT : A   A350-941 touching down on 05R at  Apr 2019 #avgeek #aviation #singaporeairlines #flymanch…',
#   '1131188835482783745'),
#  ('Another slow hand clap for  and their consistently poor baggage operation at Heathrow. 20 minutes and no sign of anyone’s bags emerging. Well done, people. https://t.co/78MgNdsJAD',
#   '1131188856911540225'),
#  ('RT : Meu sonho é termos uma RyanAir no Brasil...\n\nPassagens a 15 reais e sem firulas!! #lowCost\n\nVai quebrar as nossas em se…',
#   '1131188884933611521'),
#  ('RT : Compare to the flight from San Francisco to London to the one between London and Accra. Same phone, same . htt…',
#   '1131188893427130368'),
#  (' any sneak previews of the new Cabin Crew Uniform? https://t.co/erJbPXMhTM',
#   '1131188903698980864'),
#  ('RT : Thank you  for showing me around your Airbus A380  / First Class Suite . I enjoyed the experience 😁 i will sure…',
#   '1131188958354919425'),
#  (" We'd love to give you a hand with this. Please DM us with plenty of info about what you need help with, along with any reference numbers and your full contact details. Kris https://t.co/L1epyfzysM",
#   '1131188962452791297'),
#  ('RT : This #digital screen synchronizes with the #planes that fly over it\n\nby \n\n  …',
#   '1131188994426003457'),
#  (' It sure was😃 hopefully I’ll spot another one of your boeing 747s very soon 😎',
#   '1131189003389157378'),
#  ('  Hi, each passenger may bring a hand bag 40 x 20 x 25 included with the ticket. If you wish extra luggage you may purchase it. \nTere',
#   '1131189013434515458'),
#  ('[#LeChiffreDuJour]\n🎂 En 1974  livrait sont premier #avion à  : un #A300 -B2.\n45ans après, la cadence de production s’est accélérée pour en arriver à la livraison de son 12000e appareil : un #A220 mis en ligne pour  Air Lines ✈️\n👉 https://t.co/UAUM3NHzOn https://t.co/69eeopvSSG',
#   '1130866706409250816'),
#  ('RT : [#LeChiffreDuJour]\n🎂 En 1974  livrait sont premier #avion à  : un #A300 -B2.\n45ans après, la cadence de producti…',
#   '1131189029079343104'),
#  ('RT : Thank you  for showing me around your Airbus A380  / First Class Suite . I enjoyed the experience 😁 i will sure…',
#   '1131189029205155840'),
#  ('RT :    Because  really doesn’t care. Won’t be flying with them between U…',
#   '1131189036046049281'),
#  (" We're concerned to hear this, Eryn. Can you tell us what happened in more detail? Please DM any personal info. Steph https://t.co/L1epyfzysM",
#   '1131189036327022592'),
#  ("RT : We couldn't resist snapping these four @VirginAtlantic Boeing 747's lined up at T2 this morning 😍✈️ We can't wait for the l…",
#   '1131189060180107264'),
#  ('RT : A Lufthansa A380 under tow in Munich. https://t.co/eiD0UF13E2 © Andre M. https://t.co/Y7qJl4w1tL',
#   '1131189074360979456'),
#  ('Not often we see 4 of these beauties parked next to each other. \u2066@VirginAtlantic\u2069 \u2066\u2069 https://t.co/ZHZ00vtSHk',
#   '1131114357943865344'),
#  ('RT : Not often we see 4 of these beauties parked next to each other. \u2066@VirginAtlantic\u2069 \u2066\u2069 https://t.co/ZHZ00vtS…',
#   '1131189081579376640'),
#  ('   Yeah stopped flying    a while back... though   is tempting  me to abandon them too',
#   '1131189086717394945'),
#  ('RT : Aprovada a MP que autoriza a entrada 100% de capital estrangeiro no mercado aéreo. Na prática, além de Gol, Latam e Azul,…',
#   '1131189155843772417'),
#  ("I should rethink using @AmericanAir. Needed to change flight. Business happens. I'm Platinum Pro status w/ https://t.co/qYNFOhiWTI. Hit with fare difference + $200 change fee + $50 3rd party booking (Concur booking is standard)  may have a new customer very soon.",
#   '1131189159526379520'),
#  ('RT : I gave this a lot of thought on the plane.  I sincerely hope the reason @AmericanAir ripped up  ticket i…',
#   '1131189227465728001'),
#  ('RT @AmericanAir: Calling all athletes 🚴🏾\u200d♀️ and musicians 🎷: \n\nWhether a novice or pro, you can now travel with your sports or music equipm…',
#   '1131189221203439624'),
#  ('  Hi, if you need any assistance please contact us DM. Thank you!\nAle',
#   '1131189246914650112'),
#  (' Lamentamos esto profundamente, y esperamos que tengas buen viaje.\n\nUn cordial saludo.',
#   '1131189264077774854'),
#  ('Oh wow -  told my travel agent that they’d sorted the problem and that I wouldn’t have any problem on my return journey. But guess what: ‘Sorry, sir - we can’t check you in with a cello ‘...',
#   '1130791979741306880'),
#  ('Oh my word. If  ain’t going to take the cello of  there ain’t much hope for the rest of us. #LeaveYourBanjoAtHome',
#   '1131189274760699905'),
#  ...)

# %%
for batch in tqdm(data_batches, desc="Updating text: "):
    update_text_local(convert_to_list(batch), os.path.join(
        os.path.dirname(
            os.getcwd()
        ),
    "data_processed", "local_backup.db"))
# Out:
# Updating text: 100%|██████████| 615/615 [00:31<00:00, 19.64it/s]
